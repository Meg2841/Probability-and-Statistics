# %% [markdown]
# # IE6400 Foundations for Data Analytics Engineering
# # Fall 2024
# ### Module 2: Probability
# ### -- STUDENT VERSION --
# Meghana Sreenivasa Rao
# NUID: 002331855

# %% [markdown]
# #### Exercise 1 Probability of Drawing Two Consecutive Red Cards from Two Decks

# %% [markdown]
# **Problem Statement:**
# Suppose you have two decks of playing cards, each containing 52 cards (standard decks). What is the probability of drawing two cards consecutively (without replacement) from the two decks and both cards being red (hearts or diamonds)?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
P_red_1 = 26/52

P_red_2 = 25/51

P_combined = P_red_1*P_red_2
# ---------------------------

# Visualization
labels = ['Deck 1', 'Deck 2', 'Combined']
probabilities = [P_red_1, P_red_2, P_combined]

plt.bar(labels, probabilities, color=['red', 'blue', 'green'])
plt.ylabel('Probability')
plt.title('Probability of Drawing Red Cards Consecutively from Two Decks')
plt.ylim(0, 1)
plt.show()

print(f"Combined Probability: {P_combined:.4f}")
# Out:
# Combined Probability: 0.2451

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The code calculates the probability of drawing two consecutive red cards without replacement from a deck. The first probability is
# 0.5, and the second is 25/51, leading to a combined probability of approximately 0.2451.
# - The bar chart visualizes the individual and combined probabilities for drawing red cards from two decks, highlighting how the probability decreases after the first card is drawn. The combined probability 0.2451 represents the likelihood of drawing two red cards in a row.

# %% [markdown]
# #### Exercise 2 Probability of Drawing a Spade and then a Heart from a Standard Deck

# %% [markdown]
# **Problem Statement:**
# Suppose you have a standard deck of 52 playing cards. What is the probability of drawing a spade (one card) and then drawing a heart (without replacement)?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
P_spade = 13/52

P_heart_after_spade = 13/51

P_combined_spade_heart = P_spade*P_heart_after_spade
# ---------------------------

# Visualization
labels = ['Spade', 'Heart after Spade', 'Combined']
probabilities = [P_spade, P_heart_after_spade, P_combined_spade_heart]

plt.bar(labels, probabilities, color=['black', 'red', 'purple'])
plt.ylabel('Probability')
plt.title('Probability of Drawing a Spade and then a Heart')
plt.ylim(0, 1)
plt.show()

print(f"Combined Probability: {P_combined_spade_heart:.4f}")
# Out:
# Combined Probability: 0.0637

# %% [markdown]
# #### Write down the explanations and interpretations:
# -  Here, we calculate the probability of first drawing a spade (13/52=0.25) and then drawing a heart from the remaining 51 cards (13/51), resulting in a combined probability of approximately 0.0637.
# - The bar chart shows the individual probabilities of drawing a spade and then a heart, along with their combined probability of 0.0637. The combined value indicates the likelihood of these two events occurring in sequence from a single deck.

# %% [markdown]
# #### Exercise 3 Probability of Drawing At Least One Blue Marble

# %% [markdown]
# **Problem Statement:**
# A jar contains 30 marbles: 10 red, 15 blue, and 5 green. If you draw two marbles from the jar without replacement, what is the probability that at least one of them is blue?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
P_non_blue_1 = (10+5)/30

P_non_blue_2 = (10+5-1)/29

P_neither_blue = P_non_blue_1*P_non_blue_2

P_at_least_one_blue = 1-P_neither_blue
# ---------------------------

# Visualization
labels = ['Neither Blue', 'At Least One Blue']
probabilities = [P_neither_blue, P_at_least_one_blue]

plt.bar(labels, probabilities, color=['grey', 'blue'])
plt.ylabel('Probability')
plt.title('Probability of Drawing At Least One Blue Marble')
plt.ylim(0, 1)
plt.show()

print(f"Probability of At Least One Blue Marble: {P_at_least_one_blue:.4f}")
# Out:
# Probability of At Least One Blue Marble: 0.7586

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The code calculates the probability of drawing at least one blue marble from a set of 30 marbles, where there are 10 blue, 10 red, and 5 of another color. It first computes the probability of not drawing a blue marble in two consecutive draws, and then subtracts this from 1 to find the probability of at least one marble being blue.
# -  The bar chart shows a high probability of drawing at least one blue marble in two draws, indicating a good chance of getting a blue marble. This reflects the relatively large number of blue marbles in the set.

# %% [markdown]
# #### Exercise 4

# %% [markdown]
# **Problem Statement:**
# Two dice are rolled. What is the probability that the sum of the numbers on the dice is either 7 or 11?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
outcomes = [(i, j) for i in range(1,7) for j in range(1,7)]

favorable_outcomes = sum(1 for i, j in outcomes if i+j==7 or i+j==11)

total_outcomes = len(outcomes) 

P_7_or_11 = favorable_outcomes/total_outcomes
# ---------------------------

# Visualization
labels = ['Sum of 7 or 11', 'Other Sums']
probabilities = [P_7_or_11, 1 - P_7_or_11]

plt.bar(labels, probabilities, color=['green', 'grey'])
plt.ylabel('Probability')
plt.title('Probability of Getting a Sum of 7 or 11')
plt.ylim(0, 1)
plt.show()

print(f"Probability of Getting a Sum of 7 or 11: {P_7_or_11:.4f}")
# Out:
# Probability of Getting a Sum of 7 or 11: 0.2222

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The probability of rolling a sum of 7 or 11 with two six-sided dice is about 0.23, indicating that roughly 23% of all possible outcomes result in these sums.
# - The remaining outcomes representing other sums occur with a higher probability of around 77%, suggesting that achieving a sum of 7 or 11 is less likely compared to other sums when rolling two dice.

# %% [markdown]
# #### Exercise 5

# %% [markdown]
# **Problem Statement:** A deck of cards contains 52 cards. What is the probability of drawing a red card (hearts or diamonds) and then drawing a king from a standard deck without replacement?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
P_red = 26/52

P_king_after_red = 4/51

P_combined_red_king = P_red*P_king_after_red
# ---------------------------

# Visualization
labels = ['Red Card', 'King after Red', 'Combined']
probabilities = [P_red, P_king_after_red, P_combined_red_king]

plt.bar(labels, probabilities, color=['red', 'gold', 'purple'])
plt.ylabel('Probability')
plt.title('Probability of Drawing a Red Card and then a King')
plt.ylim(0, 1)
plt.show()

print(f"Combined Probability: {P_combined_red_king:.4f}")
# Out:
# Combined Probability: 0.0392

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The probability of drawing a red card from a standard deck is 0.50, while the probability of drawing a king after a red card has been removed is approximately 0.078.
# - The combined probability of drawing a red card followed by a king is around 0.039, indicating that this specific sequence is uncommon in a deck of cards.

# %% [markdown]
# #### Exercise 6

# %% [markdown]
# **Problem Statement:** Suppose you have a fair six-sided die. What is the probability of rolling a 4 on the first roll and then rolling a 6 on the second roll?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
P_4_first = 1/6

P_6_second = 1/6

P_combined_4_6 = P_4_first*P_6_second
# ---------------------------

# Visualization
labels = ['Roll a 4', 'Roll a 6', 'Combined']
probabilities = [P_4_first, P_6_second, P_combined_4_6]

plt.bar(labels, probabilities, color=['blue', 'yellow', 'green'])
plt.ylabel('Probability')
plt.title('Probability of Rolling a 4 and then a 6')
plt.ylim(0, 1)
plt.show()

print(f"Combined Probability: {P_combined_4_6:.4f}")
# Out:
# Combined Probability: 0.0278

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The bar graph shows equal probabilities of rolling a 4 and rolling a 6, reflecting the uniform likelihood for any specific outcome with a six-sided die.
# - The combined probability of rolling a 4 followed by a 6 is much lower (approx 0.028), as indicated by the significantly shorter green bar, depicting the reduced likelihood of getting this sequence in two consecutive rolls.

# %% [markdown]
# #### Exercise 7

# %% [markdown]
# **Problem Statement:** In a deck of playing cards, what is the probability of drawing either a red card (hearts or diamonds) or a face card (king, queen, or jack)?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
P_red = 26/52

P_face = 12/52

P_red_face = 6/52

P_combined_red_or_face = P_red+P_face-P_red_face
# ---------------------------

# Visualization
labels = ['Red Card', 'Face Card', 'Red Face Card', 'Red or Face Card']
probabilities = [P_red, P_face, P_red_face, P_combined_red_or_face]

plt.bar(labels, probabilities, color=['red', 'gold', 'purple', 'blue'])
plt.ylabel('Probability')
plt.title('Probability of Drawing a Red Card or a Face Card')
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.show()

print(f"Combined Probability: {P_combined_red_or_face:.4f}")
# Out:
# Combined Probability: 0.6154

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The red bar for drawing a red card shows a probability of 0.50, while the gold/yellow bar for drawing a face card indicates a lower probability of approx 0.2.
# - The purple bar for drawing a red face card has an even lower probability, but the blue bar representing the combined probability of drawing a red card or a face card is higher at 0.615, showing the increased likelihood of at least one of these events occurring.

# %% [markdown]
# ### Permutation and Combination:

# %% [markdown]
# #### Exercise 8
#
# **Problem Statement:** You have 5 different books, and you want to arrange them on a shelf. How many different ways can you arrange the books?

# %%
import math
import matplotlib.pyplot as plt

# --- Added the code here ---
arrangements = math.factorial(5)
# ---------------------------

# Visualization
positions = ['1st', '2nd', '3rd', '4th', '5th']
choices = [5, 4, 3, 2, 1]

plt.bar(positions, choices, color=['blue', 'green', 'red', 'purple', 'gold'])
plt.ylabel('Number of Choices')
plt.title('Number of Choices for Each Position')
plt.ylim(0, 6)
plt.show()

print(f"Total Arrangements: {arrangements}")
# Out:
# Total Arrangements: 120

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The bar graph uses different colors for each position, with the number of choices decreasing from blue (5 choices for the 1st position) to gold (1 choice for the 5th position), showing the reduction in options as positions are filled.
# - The factorial calculation give the result of the total number of arrangements as 120, calculating all possible ways to arrange five items when the number of available choices goes down by 1 with each subsequent position.

# %% [markdown]
# #### Exercise 9
#
# **Problem Statement:** A committee of 3 students is to be chosen from a group of 10 students. How many different committees can be formed?

# %%
import math
import matplotlib.pyplot as plt

# --- Added the code here ---
combinations = math.comb(10,3)
# ---------------------------

# Visualization
committee_sizes = list(range(1, 11))
combinations_for_sizes = [math.comb(10, size) for size in committee_sizes]

plt.bar(committee_sizes, combinations_for_sizes, color='skyblue')
plt.xlabel('Committee Size')
plt.ylabel('Number of Combinations')
plt.title('Number of Combinations for Different Committee Sizes')
plt.xticks(committee_sizes)
plt.show()

print(f"Number of ways to form a committee of 3 students out of 10: {combinations}")
# Out:
# Number of ways to form a committee of 3 students out of 10: 120

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The blue bars in the graph show the number of combinations for different committee sizes, peaking at a size of 5 and then symmetrically decreasing, which reflects the properties of combinations.
# - Forming a committee of 3 students out of 10 yields 120 combinations, indicating a moderate number of ways to select smaller groups compared to larger committee sizes where the number of possible selections increases.

# %% [markdown]
# #### Exercise 10
#
# **Problem Statement:** You have 6 different flavors of ice cream, and you want to create a 3-scoop ice cream cone. How many different combinations of ice cream cones can you create if the order of scoops matters (permutations) and if it doesn't matter (combinations)?

# %%
import math
import matplotlib.pyplot as plt

# --- Added the code here ---
permutations = math.perm(6,3)

combinations = math.comb(6,3)
# ---------------------------

# Visualization
labels = ['Permutations', 'Combinations']
values = [permutations, combinations]

plt.bar(labels, values, color=['lightblue', 'lightpink'])
plt.ylabel('Number of Ways')
plt.title('Number of Ways to Create a 3-Scoop Ice Cream Cone')
plt.ylim(0, max(values) + 10)
plt.show()

print(f"Number of ways (Permutations): {permutations}")
print(f"Number of ways (Combinations): {combinations}")
# Out:
# Number of ways (Permutations): 120
# Number of ways (Combinations): 20

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The light-blue bar for permutations shows a higher value (120), indicating more ways to arrange three scoops in a specific order compared to selecting three scoops without regard to order.
# - The light-pink bar for combinations is shorter (20), reflecting the fewer ways to choose three scoops when order does not matter, thus showing the difference between permutations and combinations.

# %% [markdown]
# #### Exercise 11
#
# **Problem Statement:** A basketball team consists of 12 players, and only 5 can play at a time. How many different starting lineups can the coach choose?

# %%
import math
import matplotlib.pyplot as plt

# --- Added the code here ---
combinations = math.comb(12,5)
# ---------------------------

# Visualization
lineup_sizes = list(range(1, 13))
combinations_for_sizes = [math.comb(12, size) for size in lineup_sizes]

plt.bar(lineup_sizes, combinations_for_sizes, color='orange')
plt.xlabel('Lineup Size')
plt.ylabel('Number of Combinations')
plt.title('Number of Combinations for Different Lineup Sizes')
plt.xticks(lineup_sizes)
plt.show()

print(f"Number of ways to form a starting lineup of 5 players out of 12: {combinations}")
# Out:
# Number of ways to form a starting lineup of 5 players out of 12: 792

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The orange bars show the number of combinations for different lineup sizes, with the number being the maximum at a lineup size of 6, usually the typical pattern is when the combinations increase up to the midpoint and then decreases in the same manner.
# - There are 792 ways to form a starting lineup of 5 players out of 12.

# %% [markdown]
# #### Exercise 12
#
# **Problem Statement:** A restaurant offers a menu with 10 appetizers, 15 main courses, and 8 desserts. How many different 3-course meals (1 appetizer, 1 main course, and 1 dessert) can a customer choose?

# %%
import matplotlib.pyplot as plt

# --- Added the code here ---
appetizers = 10
main_courses = 15
desserts = 8
total_meals = appetizers*main_courses*desserts
# ---------------------------

# Visualization
labels = ['Appetizers', 'Main Courses', 'Desserts', 'Total 3-Course Meals']
values = [appetizers, main_courses, desserts, total_meals]

plt.bar(labels, values, color=['lightgreen', 'lightblue', 'lightpink', 'red'])
plt.ylabel('Number of Choices')
plt.title('Number of Choices for Each Course and Total 3-Course Meals')
plt.show()

print(f"Total number of 3-course meals: {total_meals}")
# Out:
# Total number of 3-course meals: 1200

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The green, blue, and pink bars represent the number of choices for appetizers (10), main courses (15), and desserts (8), respectively, showing the variety available for each course.
# - The red bar for total 3-course meals is significantly higher at 1,200,showing the large number of possible meal combinations that can be created by selecting one option from each course.

# %% [markdown]
# #### Exercise 13
#
# **Problem Statement:** Create a function named cointoss(n). Where n indicates the number of times to toss a coin and 1 <= n <= 3
#
#
# ![Screen Shot 2023-09-20 at 22.31.10.png](data:image/png;base64,...)

# %%
import random
import matplotlib.pyplot as plt

# --- Added the code here ---
def cointoss(n):
    if n < 1 or n > 3:
        return 'Invalid number of tosses'
    results = [random.choice(['Heads', 'Tails']) for _ in range(n)]
    return results
# ---------------------------

# Test the function with 3 tosses
toss_results = cointoss(3)

# Visualization
heads_count = toss_results.count('Heads')
tails_count = toss_results.count('Tails')

plt.bar(['Heads', 'Tails'], [heads_count, tails_count], color=['blue', 'red'])
plt.ylabel('Count')
plt.title('Results of 3 Coin Tosses')
plt.show()

print(toss_results)
# Out:
# ['Heads', 'Tails', 'Heads']

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The blue bar represents the count of heads from the three coin tosses, while the red bar represents the count of tails, showcasing the results of this random experiment.
# - The visualization shows the random nature of coin tossing, with the counts varying each time the function is run, highlighting the possible outcomes in a binary experiment.

# %% [markdown]
# #### Exercise 14
# **Problem Statement:** Create a function named rolldie(n). Where n indicates the number of times to roll a die and 1 <= n <= 3
#
#
# ![Screen Shot 2023-09-20 at 22.41.06.png](data:image/png;base64,...)

# %%
import random
import matplotlib.pyplot as plt

# --- Added the code here ---
def rolldie(n):
    if n < 1 or n > 3:
        return 'Invalid number of rolls'
    results = [random.randint(1,6) for _ in range(n)]
    return results
# ---------------------------

# Test the function with 3 rolls
die_results = rolldie(3)

# Visualization
outcomes = [1, 2, 3, 4, 5, 6]
frequencies = [die_results.count(outcome) for outcome in outcomes]

plt.bar(outcomes, frequencies, color='turquoise')
plt.xlabel('Die Face')
plt.ylabel('Frequency')
plt.title('Results of 3 Die Rolls')
plt.xticks(outcomes)
plt.show()

print(die_results)
# Out:
# [2, 3, 6]

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The turquoise bars represent the frequency of each die face (1 through 6) resulting from three rolls, visually indicating how many times each number appeared.
# - The visualization depicts the randomness of rolling a die, with the counts varying with each run of the function, showing the variability in outcomes over a limited number of rolls.

# %% [markdown]
# #### Exercise 15
# **Problem Statement:** Create a probspace(experiment, n) function where the experiment can be a cointoss or a rolldie. If the option selected is cointoss, then generate a sample space and the probability for the coin toss. If the option selected is rolldie then then generate a sample space and the probability for the same.

# %%
import random
import matplotlib.pyplot as plt

# --- Added the code here ---
def probspace(experiment, n):
    if experiment == 'cointoss':
        outcomes = ['Heads', 'Tails']
        results = [random.choice(outcomes) for _ in range(n)]
    elif experiment == 'rolldie':
        outcomes = [1, 2, 3, 4, 5, 6]
        results = [random.randint(1,6) for _ in range(n)]
    else:
        return 'Invalid experiment'

    probabilities = {outcome: results.count(outcome) / n for outcome in outcomes}
    return results, probabilities
# ---------------------------

# Test the function with cointoss and 3 trials
experiment_results, experiment_probabilities = probspace('cointoss', 3)

# Visualization
labels = list(experiment_probabilities.keys())
values = list(experiment_probabilities.values())

plt.bar(labels, values, color=['purple', 'red'])
plt.ylabel('Probability')
plt.title('Probabilities for Coin Toss')
plt.show()

print(experiment_results, experiment_probabilities)
# Out:
# ['Heads', 'Heads', 'Tails'] {'Heads': 0.6666666666666666, 'Tails': 0.3333333333333333}

# %%
# Test the function with rolldie and 3 trials
experiment_results_die, experiment_probabilities_die = probspace('rolldie', 3)

# Visualization for rolldie
labels_die = list(experiment_probabilities_die.keys())
values_die = list(experiment_probabilities_die.values())

plt.bar(labels_die, values_die, color=['green', 'blue', 'red', 'yellow', 'purple', 'orange'])
plt.ylabel('Probability')
plt.title('Probabilities for Die Roll')
plt.xticks(labels_die)
plt.show()

print(experiment_results_die, experiment_probabilities_die)
# Out:
# [4, 1, 6] {1: 0.3333333333333333, 2: 0.0, 3: 0.0, 4: 0.3333333333333333, 5: 0.0, 6: 0.3333333333333333}

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The first set of bars for the coin toss shows the probabilities of landing on heads and tails, represented by the purple and red colors, respectively, based on three tosses.
# - The second set of bars for the die roll presents the probabilities for each face (1 through 6), with colors ranging from green to orange, highlighting how often each number appeared in three rolls, showing the random nature of the experiment.

# %% [markdown]
# ### Probability Distributions

# %% [markdown]
# #### Exercise 16
# Suppose the height (in centimeters) of adult males in a population follows a normal distribution with a mean (μ) of 175 cm and a standard deviation (σ) of 7 cm. Calculate the probability that a randomly selected adult male is between 165 cm and 185 cm tall.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# --- Added the code here ---
mu = 175
sigma = 7

z_score_165 = (165-mu)/sigma
z_score_185 = (185-mu)/sigma

probability = stats.norm.cdf(z_score_185)-stats.norm.cdf(z_score_165)
# ---------------------------

# Visualization
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y = stats.norm.pdf(x, mu, sigma)

plt.plot(x, y, 'r-', lw=2)
plt.fill_between(x, y, where=((x > 165) & (x < 185)), color='magenta', alpha=0.4)
plt.title('Normal Distribution of Adult Male Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

print(f"Probability that a randomly selected adult male is between 165 cm and 185 cm tall: {probability:.4f}")
# Out:
# Probability that a randomly selected adult male is between 165 cm and 185 cm tall: 0.8469

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The red curve shows the normal distribution of adult male heights, with height in centimeters on the x-axis and probability density on the y-axis.
# - The shaded magenta area between 165 cm and 185 cm represents the probability that a randomly selected adult male falls within this height range, which is about 0.8469, showing a large portion of the population.

# %% [markdown]
# #### Exercise 17 Probability Density Function (PDF) for Adult Heights

# %% [markdown]
# **Problem Statement:**
# Given a dataset of adult heights, calculate the probability density function (PDF) for the height of adults within a certain range.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(0)

# --- Added the code here ---
mean_height = 170
std_deviation = 10
num_samples = 1000

heights_data = np.random.normal(mean_height, std_deviation, num_samples)

min_height = 150
max_height = 190

filtered_heights = heights_data[(heights_data >= min_height) & (heights_data <= max_height)]

hist, bin_edges = np.histogram(filtered_heights, bins=20, density=True)

bin_width = bin_edges[1] - bin_edges[0]

pdf = hist/(bin_width*np.sum(hist))
# ---------------------------

# Create a plot to visualize the PDF
plt.figure(figsize=(8, 6))
plt.bar(bin_edges[:-1], pdf, width=bin_width, align='edge', color='grey')
plt.title('Probability Density Function (PDF) of Adult Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The grey bars represent the probability density function (PDF) of adult heights, with height in centimeters on the x-axis and probability density on the y-axis.
# - The histogram shows the distribution of filtered heights between 150 cm and 190 cm, providing a visualization of how adult heights are spread within this range.

# %% [markdown]
# #### Exercise 18 Probability of Height Between 165 cm and 185 cm

# %% [markdown]
# **Problem Statement:**
# Suppose the height (in centimeters) of adult males in a population follows a normal distribution with a mean (μ) of 175 cm and a standard deviation (σ) of 7 cm. Calculate the probability that a randomly selected adult male is between 165 cm and 185 cm tall.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# --- Added the code here ---
mean_height = 175
std_deviation = 7

min_height = 165
max_height = 185

z_score_min = (min_height - mean_height) / std_deviation
z_score_max = (max_height - mean_height) / std_deviation

probability = stats.norm.cdf(z_score_max) - stats.norm.cdf(z_score_min)
# ---------------------------

# Create a visual representation of the probability
x = np.linspace(mean_height - 3 * std_deviation, mean_height + 3 * std_deviation, 1000)
y = stats.norm.pdf(x, mean_height, std_deviation)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='Normal Distribution PDF', color='blue')
plt.fill_between(x, 0, y, where=(x >= min_height) & (x <= max_height), alpha=0.3, color='pink', label='Probability')
plt.title('Probability of Adult Male Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Probability Density')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# Output the calculated probability
print(f"Probability that a randomly selected adult male is between {min_height} cm and {max_height} cm tall: {probability:.4f}")
# Out:
# Probability that a randomly selected adult male is between 165 cm and 185 cm tall: 0.8469

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The blue line represents the normal distribution of adult male heights, with height in centimeters on the x-axis and probability density on the y-axis.
# - The pink shaded area between 165 cm and 185 cm indicates the probability that a randomly selected adult male falls within this height range, which is about 0.8469, showing a significant portion of the population.

# %% [markdown]
# ### Bayes' Theorem

# %% [markdown]
# #### Exercise 19 Probability of Having the Disease Given a Positive Test Result

# %% [markdown]
# **Problem Statement:**
# A medical test is used to diagnose a rare disease. The test is 98% accurate when the disease is present and correctly identifies a healthy person 95% of the time. The disease occurs in 1% of the population. If a person tests positive, what is the probability that they actually have the disease?

# %%
# --- Added the code here ---
p_disease = 0.01
p_no_disease = 1-p_disease

p_positive_given_disease = 0.98

p_negative_given_no_disease = 0.95

p_positive = (p_disease *p_positive_given_disease) + (p_no_disease * (1 - p_negative_given_no_disease))

p_disease_given_positive = (p_disease * p_positive_given_disease) / p_positive
# ---------------------------

# Output the result
print(f"Probability that a person who tests positive actually has the disease: {p_disease_given_positive:.4f}")
# Out:
# Probability that a person who tests positive actually has the disease: 0.1653

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The probability that a person who tests positive actually has the disease is approximately 0.1653, indicating that a positive result does not guarantee the presence of the disease, especially given its low occurance.
# - This highlights the importance of considering both the accuracy of the test and the overall prevalence of the disease when interpreting test results.

# %% [markdown]
# #### Exercise 20 Probability of a Defective Bulb Coming from Machine A

# %% [markdown]
# **Problem Statement:**
# A factory produces light bulbs using two machines (Machine A and Machine B). Machine A produces 60% of the bulbs, while Machine B produces 40%. Machine A's bulbs have a defect rate of 5%, while Machine B's bulbs have a defect rate of 3%. If a randomly selected bulb is defective, what is the probability that it came from Machine A?

# %%
# --- Added the code here ---
p_machine_A = 0.60
p_machine_B = 0.40

p_defect_given_A =0.05 
p_defect_given_B = 0.03

p_defect = (p_machine_A * p_defect_given_A) + (p_machine_B * p_defect_given_B)

p_machine_A_given_defect = (p_machine_A * p_defect_given_A) / p_defect
# ---------------------------

# Output the result
print(f"Probability that a randomly selected defective bulb came from Machine A: {p_machine_A_given_defect:.4f}")
# Out:
# Probability that a randomly selected defective bulb came from Machine A: 0.7143

# %% [markdown]
# #### Write down the explanations and interpretations:
# - The probability that a randomly selected defective bulb came from Machine A is approximately 0.7143.
# - This indicates that if a bulb is found to be defective, there is a 71.43% chance it was produced by Machine A, considering the defect rates of both machines and their respective production proportions.

# %% [markdown]
# ---

# %% [markdown]
# #### Revised Date: August 7, 2024
